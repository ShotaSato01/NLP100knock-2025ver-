# %%
N = 10
with open('../../code/2/popular-names.txt') as f:
    count = 0
    for line in f:
        line = line.split("\t")
        print(line[0])
        count += 1
        if count == N:
            break
# Out:
# Mary
# Anna
# Emma
# Elizabeth
# Minnie
# Margaret
# Ida
# Alice
# Bertha
# Sarah

# %% [markdown]
# UNIXコマンド
# head code/2/popular-names.txt | cut -f 1
#
# 実行結果
# Mary
# Anna
# Emma
# Elizabeth
# Minnie
# Margaret
# Ida
# Alice
# Bertha
# Sarah
