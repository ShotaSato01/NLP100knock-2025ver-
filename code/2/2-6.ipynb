# %%
import random

with open('../../code/2/popular-names.txt') as f:
    content = f.readlines()

length = len(content)

ls = random.sample(range(0,length),length)

for i in ls:
    with open("output2_6.txt","a") as f:
        f.write(content[i])

# %% [markdown]
# UNIXコマンド
# brew install coreutils（macにはshufコマンドがない）
#
# gshuf  'code/2/popular-names.txt' > UNIX2_6.txt
