# %%
GROQ_API_KEY = "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"

# %%
from groq import Groq

client = Groq(api_key=GROQ_API_KEY)  # または os.environ.get("GROQ_API_KEY")

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "Please translate your response in Japanese. And answer only in Japanese.",
        },
        {
            "role": "user",
            "content": """
                        9世紀に活躍した人物に関係するできごとについて述べた次のア～ウを年代の古い順に正しく並べよ。

                        ア　藤原時平は，策謀を用いて菅原道真を政界から追放した。
                        イ　嵯峨天皇は，藤原冬嗣らを蔵人頭に任命した。
                        ウ　藤原良房は，承和の変後，藤原氏の中での北家の優位を確立した。
                        """
        }
    ],
    model="llama3-8b-8192",  # ← 新しい有効なモデルを指定
)

print(chat_completion.choices[0].message.content)
# Out:
# 9世紀に関係するできごと
#
# ア　イは誤り嵯峨天皇は宝亀6年（775年）に即位したため、藤原冬嗣の蔵人頭任命は早い
# ウ　イは誤り藤原良房は承和の変後である嘉祥元年（850年）に藤原北家の流れを確立したとして良房誕生の50年間くらい以前に生きなかった
#
# 正しく並べば
#
# ア　藤原良房は承和の変後、嘉祥元年（850年）に藤原北家の流れを確立した。
# イ　嵯峨天皇は宝亀6年（775年）に即位した。
# ウ　藤原時平は、菅原道真を政界から追放した。
#
# _translation_
#
# Events related to 9th century people
#
# A-I is incorrect. It is an error that Emperor Saga was appointed to the Head of the Storehouse in 775 (宝亀6年), when in fact he ascended to the throne in 775 (宝亀6年).
# U-I is incorrect. It is an error that Fujiwara no Sukeakira established the Fujiwara northern branch after the Iwashimizu incident, and instead was born around 50 years before that.
#
# In the correct order:
#
# A. Fujiwara no Sukeakira established the Fujiwara northern branch in 850 (嘉祥元年) after the Iwashimizu incident.
# B. Emperor Saga ascended to the throne in 775 (宝亀6年).
# C. Fujiwara no Saneyori had phongreal politics and expelled Sugawara no Michizane from the political world.
