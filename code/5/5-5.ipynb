# %%
from groq import Groq

client = Groq(api_key=GROQ_API_KEY)  # または os.environ.get("GROQ_API_KEY")

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "Please generate your response in Japanese.",
        },
        {
            "role": "user",
            "content": """
                        つばめちゃんは渋谷駅から東急東横線に乗り、自由が丘駅で乗り換えました。東急大井町線の大井町方面の電車に乗り換えたとき、各駅停車に乗車すべきところ、間違えて急行に乗車してしまったことに気付きました。自由が丘の次の急行停車駅で降車し、反対方向の電車で一駅戻った駅がつばめちゃんの目的地でした。目的地の駅の名前を答えてください。
                        """
        }
    ],
    model="meta-llama/llama-4-maverick-17b-128e-instruct",  # ← 新しい有効なモデルを指定
)

print(chat_completion.choices[0].message.content)
print("---------------------------------------------------------------------------------------")

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "Please generate your response in Japanese.",
        },
        {
            "role": "user",
            "content": """
                        さらに、つばめちゃんが自由が丘駅で乗り換えたとき、先ほどとは反対方向の急行電車に間違って乗車してしまった場合を考えます。目的地の駅に向かうため、自由が丘の次の急行停車駅で降車した後、反対方向の各駅停車に乗車した場合、何駅先の駅で降りれば良いでしょうか？
                        """
        }
    ],
    model="meta-llama/llama-4-maverick-17b-128e-instruct",  # ← 新しい有効なモデルを指定
)

print(chat_completion.choices[0].message.content)
# Out:
# 東急大井線の自由が丘の次の急行停車駅は「二子玉川」です。
# 二子玉川から反対方向の電車で一駅戻ると「上野毛」です。
# したがって、つばめちゃんの目的地は上野毛駅です。
# ---------------------------------------------------------------------------------------
# 自由が丘駅で反対方向の急行電車に乗ってしまった場合、急行停車駅は二子玉川駅なので、そこで降車することになります。二子玉川駅で反対方向（元の進行方向）の各駅停車に乗ると、次の停車駅は二子新地駅、さらに次の停車駅は高津駅となります。したがって、二子玉川駅で各駅停車に乗り換えた場合、2駅先の高津駅で降りればよいことになります。答えは2駅先です。
