# %%
import MeCab

text = """
メロスは激怒した。
必ず、かの邪智暴虐の王を除かなければならぬと決意した。
メロスには政治がわからぬ。
メロスは、村の牧人である。
笛を吹き、羊と遊んで暮して来た。
けれども邪悪に対しては、人一倍に敏感であった。
"""

def tokenize_with_pos(text):
    mecab = MeCab.Tagger()
    nodes = mecab.parseToNode(text)
    tokens = []
    while nodes:
        if nodes.surface != "":
            tokens.append((nodes.surface, nodes.feature.split(',')[0]))
        nodes = nodes.next
    return tokens

# 使用例
tokens_with_pos = tokenize_with_pos(text)
print(tokens_with_pos)

for surface,pos in tokens_with_pos:
    if pos == "動詞":
        print(surface)
# Out:
# [('メロス', '名詞'), ('は', '助詞'), ('激怒', '名詞'), ('し', '動詞'), ('た', '助動詞'), ('。', '補助記号'), ('必ず', '副詞'), ('、', '補助記号'), ('かの', '連体詞'), ('邪智', '名詞'), ('暴虐', '名詞'), ('の', '助詞'), ('王', '名詞'), ('を', '助詞'), ('除か', '動詞'), ('なけれ', '助動詞'), ('ば', '助詞'), ('なら', '動詞'), ('ぬ', '助動詞'), ('と', '助詞'), ('決意', '名詞'), ('し', '動詞'), ('た', '助動詞'), ('。', '補助記号'), ('メロス', '名詞'), ('に', '助詞'), ('は', '助詞'), ('政治', '名詞'), ('が', '助詞'), ('わから', '動詞'), ('ぬ', '助動詞'), ('。', '補助記号'), ('メロス', '名詞'), ('は', '助詞'), ('、', '補助記号'), ('村', '名詞'), ('の', '助詞'), ('牧人', '名詞'), ('で', '助動詞'), ('ある', '動詞'), ('。', '補助記号'), ('笛', '名詞'), ('を', '助詞'), ('吹き', '動詞'), ('、', '補助記号'), ('羊', '名詞'), ('と', '助詞'), ('遊ん', '動詞'), ('で', '助詞'), ('暮し', '動詞'), ('て', '助詞'), ('来', '動詞'), ('た', '助動詞'), ('。', '補助記号'), ('けれど', '接続詞'), ('も', '助詞'), ('邪悪', '名詞'), ('に', '助詞'), ('対し', '動詞'), ('て', '助詞'), ('は', '助詞'), ('、', '補助記号'), ('人', '名詞'), ('一', '名詞'), ('倍', '名詞'), ('に', '助詞'), ('敏感', '名詞'), ('で', '助動詞'), ('あっ', '動詞'), ('た', '助動詞'), ('。', '補助記号')]
# し
# 除か
# なら
# し
# わから
# ある
# 吹き
# 遊ん
# 暮し
# 来
# 対し
# あっ
