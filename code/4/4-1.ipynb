# %%
import MeCab

text = """
メロスは激怒した。
必ず、かの邪智暴虐の王を除かなければならぬと決意した。
メロスには政治がわからぬ。
メロスは、村の牧人である。
笛を吹き、羊と遊んで暮して来た。
けれども邪悪に対しては、人一倍に敏感であった。
"""

def tokenize_with_pos(text):
    mecab = MeCab.Tagger()
    nodes = mecab.parseToNode(text)
    tokens = []
    while nodes:
        if nodes.surface != "":
            tokens.append((nodes.surface, nodes.feature.split(',')[0], nodes.feature.split(',')[6]))
        nodes = nodes.next
    return tokens

# 使用例
tokens_with_pos = tokenize_with_pos(text)
print(tokens_with_pos)

for surface,pos,basic in tokens_with_pos:
    if pos == "動詞":
        print(surface,basic)
# Out:
# [('メロス', '名詞', 'メロス'), ('は', '助詞', 'ハ'), ('激怒', '名詞', 'ゲキド'), ('し', '動詞', 'スル'), ('た', '助動詞', 'タ'), ('。', '補助記号', ''), ('必ず', '副詞', 'カナラズ'), ('、', '補助記号', ''), ('かの', '連体詞', 'カノ'), ('邪智', '名詞', 'ジャチ'), ('暴虐', '名詞', 'ボウギャク'), ('の', '助詞', 'ノ'), ('王', '名詞', 'オウ'), ('を', '助詞', 'ヲ'), ('除か', '動詞', 'ノゾク'), ('なけれ', '助動詞', 'ナイ'), ('ば', '助詞', 'バ'), ('なら', '動詞', 'ナル'), ('ぬ', '助動詞', 'ズ'), ('と', '助詞', 'ト'), ('決意', '名詞', 'ケツイ'), ('し', '動詞', 'スル'), ('た', '助動詞', 'タ'), ('。', '補助記号', ''), ('メロス', '名詞', 'メロス'), ('に', '助詞', 'ニ'), ('は', '助詞', 'ハ'), ('政治', '名詞', 'セイジ'), ('が', '助詞', 'ガ'), ('わから', '動詞', 'ワカル'), ('ぬ', '助動詞', 'ズ'), ('。', '補助記号', ''), ('メロス', '名詞', 'メロス'), ('は', '助詞', 'ハ'), ('、', '補助記号', ''), ('村', '名詞', 'ムラ'), ('の', '助詞', 'ノ'), ('牧人', '名詞', 'ボクジン'), ('で', '助動詞', 'ダ'), ('ある', '動詞', 'アル'), ('。', '補助記号', ''), ('笛', '名詞', 'フエ'), ('を', '助詞', 'ヲ'), ('吹き', '動詞', 'フク'), ('、', '補助記号', ''), ('羊', '名詞', 'ヒツジ'), ('と', '助詞', 'ト'), ('遊ん', '動詞', 'アソブ'), ('で', '助詞', 'テ'), ('暮し', '動詞', 'クラス'), ('て', '助詞', 'テ'), ('来', '動詞', 'クル'), ('た', '助動詞', 'タ'), ('。', '補助記号', ''), ('けれど', '接続詞', 'ケレド'), ('も', '助詞', 'モ'), ('邪悪', '名詞', 'ジャアク'), ('に', '助詞', 'ニ'), ('対し', '動詞', 'タイスル'), ('て', '助詞', 'テ'), ('は', '助詞', 'ハ'), ('、', '補助記号', ''), ('人', '名詞', 'ヒト'), ('一', '名詞', 'イチ'), ('倍', '名詞', 'バイ'), ('に', '助詞', 'ニ'), ('敏感', '名詞', 'ビンカン'), ('で', '助動詞', 'ダ'), ('あっ', '動詞', 'アル'), ('た', '助動詞', 'タ'), ('。', '補助記号', '')]
# し スル
# 除か ノゾク
# なら ナル
# し スル
# わから ワカル
# ある アル
# 吹き フク
# 遊ん アソブ
# 暮し クラス
# 来 クル
# 対し タイスル
# あっ アル
