# %%
#自然言語処理用のgensimパッケージ
from gensim.models import KeyedVectors

file = '../../code/6/GoogleNews-vectors-negative300.bin'
#fileをword2vec形式で読み込み
model = KeyedVectors.load_word2vec_format(file,binary = True)


# 単語の取得
file = '../../code/6/countries.txt'                         #2行目に国名が含まれているカテゴリ                         
countries = set()                                                                       
with open(file, 'r', encoding='utf-8') as f:
    for row in f:
        if row.strip() in model:                  #modelに含まれている単語を取得                                                              
            countries.add(row.strip())                                     

countries = list(countries)                                                              
print(len(countries))
print(countries)                                         

# 単語ベクトルの取得
countries_vec = [model[country] for country in countries]
# Out:
# 177
# ['Tunisia', 'Seychelles', 'Guyana', 'Uganda', 'Barbados', 'Kazakhstan', 'Jordan', 'Afghanistan', 'Brazil', 'Burkina_Faso', 'Eritrea', 'Luxembourg', 'Somalia', 'Comoros', 'Mauritius', 'Japan', 'Palau', 'Italy', 'Cameroon', 'Bosnia_Herzegovina', 'Kyrgyzstan', 'Vanuatu', 'Tajikistan', 'Egypt', 'San_Marino', 'Mexico', 'Ukraine', 'Samoa', 'New_Zealand', 'Uruguay', 'Hungary', 'India', 'Algeria', 'Monaco', 'Latvia', 'Malaysia', 'Czech_Republic', 'Gabon', 'Sudan', 'Malta', 'Syria', 'Grenada', 'Sri_Lanka', 'Moldova', 'Switzerland', 'Andorra', 'Libya', 'Maldives', 'Guatemala', 'Bulgaria', 'Equatorial_Guinea', 'Nicaragua', 'South_Africa', 'Nepal', 'Oman', 'Liberia', 'Senegal', 'Ghana', 'Jamaica', 'Iraq', 'Peru', 'Tuvalu', 'Chad', 'Finland', 'Malawi', 'Nauru', 'Montenegro', 'Serbia', 'Congo', 'Dominica', 'Zambia', 'Paraguay', 'Cuba', 'Dominican_Republic', 'Germany', 'Angola', 'Australia', 'Guinea_Bissau', 'Kiribati', 'Korea', 'Singapore', 'Turkey', 'Guinea', 'Israel', 'Indonesia', 'Bahamas', 'Albania', 'Denmark', 'Myanmar', 'Antigua_Barbuda', 'Spain', 'Yemen', 'Fiji', 'Burundi', 'Sweden', 'Brunei', 'Belgium', 'Liechtenstein', 'Netherlands', 'Bangladesh', 'Colombia', 'Iceland', 'Thailand', 'Lesotho', 'Uzbekistan', 'Saint_Lucia', 'Niger', 'Suriname', 'Venezuela', 'Austria', 'Djibouti', 'Gambia', 'Kenya', 'Morocco', 'Botswana', 'Iran', 'Madagascar', 'Zimbabwe', 'Argentina', 'Lithuania', 'Lebanon', 'United_Arab_Emirates', 'Micronesia', 'Kuwait', 'Georgia', 'Philippines', 'Ecuador', 'Mozambique', 'Bhutan', 'Cambodia', 'France', 'Saudi_Arabia', 'Honduras', 'Croatia', 'Russian', 'Canada', 'Greece', 'Ireland', 'Bahrain', 'Bolivia', 'Mongolia', 'Mali', 'Timor_Leste', 'Nigeria', 'United_States', 'Norway', 'Marshall_Islands', 'Azerbaijan', 'Pakistan', 'Qatar', 'Belize', 'Tonga', 'Portugal', 'Cyprus', 'Benin', 'Panama', 'Slovakia', 'Cabo_Verde', 'Togo', 'Sierra_Leone', 'Solomon_Islands', 'Estonia', 'Belarus', 'El_Salvador', 'Mauritania', 'Slovenia', 'Turkmenistan', 'Chile', 'Ethiopia', 'Haiti', 'Poland', 'Romania', 'Rwanda', 'Armenia', 'Namibia', 'China', 'United_Kingdom']

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram

linkage_result = linkage(countries_vec, method='ward')         #階層型クラスリングの実行

plt.figure(figsize=(16, 9))
dendrogram(linkage_result, labels=countries)                   #dendrogramによって、階層型クラスタリングの結果を表示
plt.savefig('output6-8.png')                                       #結果を画像として保存
plt.show()
