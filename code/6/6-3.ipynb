# %%
#自然言語処理用のgensimパッケージ
from gensim.models import KeyedVectors
file = '../../code/6/GoogleNews-vectors-negative300.bin'
#fileをword2vec形式で読み込み
model = KeyedVectors.load_word2vec_format(file,binary = True)

#most_similarでコサイン類似度による比較
#引数の中で加算するベクトルと減算するベクトルを指定
res = model.most_similar(positive=['Spain','Athens'],negative=['Madrid'],topn=10)
for i,x in enumerate(res):
    print(i+1,x[0],x[1])
# Out:
# 1 Greece 0.6898480653762817
# 2 Aristeidis_Grigoriadis 0.560684859752655
# 3 Ioannis_Drymonakos 0.555290937423706
# 4 Greeks 0.5450686812400818
# 5 Ioannis_Christou 0.5400862693786621
# 6 Hrysopiyi_Devetzi 0.5248445272445679
# 7 Heraklio 0.5207759141921997
# 8 Athens_Greece 0.5168809294700623
# 9 Lithuania 0.5166866183280945
# 10 Iraklion 0.5146791934967041
