# %%
import re
with open("../../code/3/text_US.txt","r") as f:
    content = f.readlines()

for i in content:
    line = i.replace("\n","")
    pattern = r'\[\[Category:(.*)'
    output = re.match(pattern,line)

    if output:
        print(output.group())
# Out:
# [[Category:イギリス|*]]
# [[Category:イギリス連邦加盟国]]
# [[Category:英連邦王国|*]]
# [[Category:G8加盟国]]
# [[Category:欧州連合加盟国|元]]
# [[Category:海洋国家]]
# [[Category:現存する君主国]]
# [[Category:島国]]
# [[Category:1801年に成立した国家・領域]]
