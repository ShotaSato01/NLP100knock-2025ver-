# %%
import re
with open("../../code/3/text_US.txt","r") as f:
    content = f.readlines()

dic = {}
for i in content:
    line = i.replace("\n","")
    pattern = r'\|(.*)= (.*)'
    output = re.match(pattern,line)

    if output:
        dic[output.group(1)] = re.sub(r'\'*|\[*|\]*|{*|}*',"",output.group(2))

# %%
import requests

S = requests.Session()

URL = "https://en.wikipedia.org/w/api.php"

PARAMS = {
    "action": "query",
    "format": "json",
    "prop": "imageinfo",
    "titles": f"File:{dic['国旗画像 ']}",
    "iiprop":"url"
}

R = S.get(url=URL, params=PARAMS)
DATA = R.json()

PAGES = DATA["query"]["pages"]

for k, v in PAGES.items():
    print(v["title"] + " is uploaded by : " + v["imageinfo"][0]["url"])
# Out:
# File:Flag of the United Kingdom.svg is uploaded by : https://upload.wikimedia.org/wikipedia/en/a/ae/Flag_of_the_United_Kingdom.svg
